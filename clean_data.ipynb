# %%
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None  # default='warn', Mutes warnings when copying a slice from a DataFrame.

# %%
# Load the TSV file, ignoring lines that start with '#'
articles = pd.read_csv('data/wikispeedia_paths-and-graph/articles.tsv', sep='\t', comment='#')
categories = pd.read_csv('data/wikispeedia_paths-and-graph/categories.tsv', sep='\t', comment='#')
links = pd.read_csv('data/wikispeedia_paths-and-graph/links.tsv', sep='\t', comment='#')
paths_finished = pd.read_csv('data/wikispeedia_paths-and-graph/paths_finished.tsv', sep='\t', comment='#')
paths_unfinished = pd.read_csv('data/wikispeedia_paths-and-graph/paths_unfinished.tsv', sep='\t', comment='#')
shortest_path = pd.read_csv('data/wikispeedia_paths-and-graph/shortest-path-distance-matrix.txt', sep='\t', comment='#', header=None)

# %%
links.columns = ['linkSource', 'linkTarget']
paths_finished.columns = ['hashedIpAddress', 'timestamp', 'durationInSec', 'path', 'rating']
paths_unfinished.columns = ['hashedIpAddress', 'timestamp', 'durationInSec', 'path', 'target', 'type']
paths_finished['status'] = 'finished'
paths_unfinished['status'] = 'unfinished'

# Concatenate the dataframes with the added 'status' column
concatenated_df = pd.concat(
    [
        paths_finished[['hashedIpAddress', 'timestamp', 'durationInSec', 'path', 'rating', 'status']],
        paths_unfinished[['hashedIpAddress', 'timestamp', 'durationInSec', 'path', 'target', 'type', 'status']]
    ],
    ignore_index=True
)

# %%
# Create a copy of concatenated_df to avoid modifying the original DataFrame
clean_merge = concatenated_df.copy()

# Modify 'durationInSec' in the new DataFrame based on the condition
for index, row in clean_merge.iterrows():
    if row['type'] == 'timeout':  # Check if the last element in 'path' is 'timeout'
        clean_merge.loc[index, 'durationInSec'] -= 1800  # Subtract 1800 from 'durationInSec'

# %%
# Process each row based on 'status' and set 'target' accordingly
for i, row in clean_merge.iterrows():
    if row['status'] == 'finished':
        # Split the path and select the last element
        path_segments = row['path'].split(';') if pd.notnull(row['path']) else []
        row['target'] = path_segments[-1]

# To apply these changes to the DataFrame directly
clean_merge.loc[clean_merge['status'] == 'finished', 'target'] = clean_merge['path'].dropna().str.split(';').str[-1]

# %%
clean_merge.to_csv('clean_merge.csv')

# %%
clean_merge.sample(10)
# Out:
#         hashedIpAddress   timestamp  durationInSec  \
# 57039  100f45996ea4adac  1315850893             38
# 57634  76baa89b5bf0f0df  1321294639            353
# 47385  738879d35f1e86e9  1273978895             97
# 42770  4398032616bb1310  1254007062             62
# 49933  11f274a11b01180a  1259068550             31
# 54026  2325e8e4315b363c  1303848450             30
# 3292   04f22b1a33430c59  1315577149             17
# 61988  5dbec8a62ba71d41  1344969761              7
# 40070  65a490c216191d92  1313539314            255
# 45759  0e3862ef0943ac7c  1249912167             47
#
#                                                     path  rating      status  \
# 57039  Minneapolis%2C_Minnesota;United_States;Preside...     NaN  unfinished
# 57634      Drum_and_bass;Bristol;Ice_age;Climate;Weather     NaN  unfinished
# 47385  Stegosaurus;East_Africa;Indian_Ocean;Australia...     NaN    finished
# 42770  Margaret_Sanger;United_States;Pacific_Ocean;Af...     NaN    finished
# 49933          Van_Halen;Guitar;Musical_instrument;Flute     1.0    finished
# 54026                                      Lusaka;Europe     NaN  unfinished
# 3292   Climate_change;North_Atlantic_oscillation;El_N...     1.0    finished
# 61988                                 Aluminium_chloride     NaN  unfinished
# 40070  Hello_Garci_scandal;Philippines;English_langua...     5.0    finished
# 45759  Rail_transport;Iron;Manganese;Chromium;Molybde...     1.0    finished
#
#                                   target     type
# 57039       Religious_Society_of_Friends  restart
# 57634                               Soil  restart
# 47385                           Kangaroo      NaN
# 42770                     Western_Sahara      NaN
# 49933                              Flute      NaN
# 54026  Edward_VIII_of_the_United_Kingdom  restart
# 3292   El_Ni%C3%B1o-Southern_Oscillation      NaN
# 61988                       Ku_Klux_Klan  restart
# 40070                      Francis_Drake      NaN
# 45759                            Niobium      NaN

# %%
clean_merge.fillna('finished', inplace=True)
clean_merge.sample(10)
# Out:
# /var/folders/hy/zygvvrm928n5d36wdcsnnkg40000gn/T/ipykernel_11115/291672045.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'finished' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   clean_merge.fillna('finished', inplace=True)
#         hashedIpAddress   timestamp  durationInSec  \
# 29218  0d57c8c57d75e2f5  1288191394            160
# 4713   0b415aa936f6b968  1351200482            160
# 70429  73319ffd63eac41d  1368644071             30
# 75936  538bf36b082c7dd1  1388948446           1178
# 14843  3504af4953148500  1348614073            108
# 72982  126c53a444812f50  1378744525              7
# 9372   5ee218bb01627793  1241160612            296
# 66112  4d5e123b578dc965  1353891168             78
# 19154  4336d85339763f62  1222831965             51
# 52981  282cc7a66f3d1d6c  1299795687            168
#
#                                                     path    rating  \
# 29218  The_Temptations;United_States;North_America;So...       1.0
# 4713   French_Revolution;Famine;Agriculture;Fossil_fu...  finished
# 70429                         Action_potential;Giraffe;<  finished
# 75936  Jazz;United_States;Moon;Solar_System;Sun;Star;...  finished
# 14843  Brain;Cell_%28biology%29;Human;Communication;T...       1.0
# 72982                                Famine;Soviet_Union  finished
# 9372   Russian_language;English_language;Liverpool;Lo...  finished
# 66112                   Star_Trek;War;Market;Information  finished
# 19154       Socialism;Egypt;North_Africa;Africa;Tanzania       2.0
# 52981  Sunlight;Earth;German_language;Germany;Gottfri...  finished
#
#            status                  target      type
# 29218    finished                   Chile  finished
# 4713     finished                 Calcium  finished
# 70429  unfinished            The_Simpsons   timeout
# 75936  unfinished                16_Cygni   timeout
# 14843    finished               Telephone  finished
# 72982  unfinished                  Arctic   restart
# 9372     finished              Tim_Henman  finished
# 66112  unfinished        Aircraft_carrier   restart
# 19154    finished                Tanzania  finished
# 52981  unfinished  Johann_Wolfgang_Goethe   timeout
