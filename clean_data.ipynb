# %%
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None  # default='warn', Mutes warnings when copying a slice from a DataFrame.

# %%
# Load the TSV file, ignoring lines that start with '#'
articles = pd.read_csv('data/wikispeedia_paths-and-graph/articles.tsv', sep='\t', comment='#')
categories = pd.read_csv('data/wikispeedia_paths-and-graph/categories.tsv', sep='\t', comment='#')
links = pd.read_csv('data/wikispeedia_paths-and-graph/links.tsv', sep='\t', comment='#')
paths_finished = pd.read_csv('data/wikispeedia_paths-and-graph/paths_finished.tsv', sep='\t', comment='#')
paths_unfinished = pd.read_csv('data/wikispeedia_paths-and-graph/paths_unfinished.tsv', sep='\t', comment='#')
shortest_path = pd.read_csv('data/wikispeedia_paths-and-graph/shortest-path-distance-matrix.txt', sep='\t', comment='#', header=None)

# %%
links.columns = ['linkSource', 'linkTarget']
paths_finished.columns = ['hashedIpAddress', 'timestamp', 'durationInSec', 'path', 'rating']
paths_unfinished.columns = ['hashedIpAddress', 'timestamp', 'durationInSec', 'path', 'target', 'type']
paths_finished['status'] = 'finished'
paths_unfinished['status'] = 'unfinished'

# Concatenate the dataframes with the added 'status' column
concatenated_df = pd.concat(
    [
        paths_finished[['hashedIpAddress', 'timestamp', 'durationInSec', 'path', 'rating', 'status']],
        paths_unfinished[['hashedIpAddress', 'timestamp', 'durationInSec', 'path', 'target', 'type', 'status']]
    ],
    ignore_index=True
)

# %%
# Create a copy of concatenated_df to avoid modifying the original DataFrame
clean_merge = concatenated_df.copy()

# Modify 'durationInSec' in the new DataFrame based on the condition
for index, row in clean_merge.iterrows():
    if row['type'] == 'timeout':  # Check if the last element in 'path' is 'timeout'
        clean_merge.loc[index, 'durationInSec'] -= 1800  # Subtract 1800 from 'durationInSec'

# %%
# Process each row based on 'status' and set 'target' accordingly
for i, row in clean_merge.iterrows():
    if row['status'] == 'finished':
        # Split the path and select the last element
        path_segments = row['path'].split(';') if pd.notnull(row['path']) else []
        row['target'] = path_segments[-1]

# To apply these changes to the DataFrame directly
clean_merge.loc[clean_merge['status'] == 'finished', 'target'] = clean_merge['path'].dropna().str.split(';').str[-1]

# %%
clean_merge.sample(10)
# Out:
#         hashedIpAddress   timestamp  durationInSec  \
# 20240  556610582b5fc732  1274264145            401
# 25087  613cfa1c05cbbf9d  1222885439            127
# 57329  3316cb8866a15793  1318658202            151
# 5411   4207817a7bf1fcec  1272442921             43
# 76148  3f166d0a191b66e6  1389688545             30
# 3657   482972df0e234ce2  1260239473            167
# 3537   7f930cd75dc18bcc  1329753073             76
# 17751  75bd20c663d02c8f  1365713435             84
# 39333  08e189ab09da7db4  1230084658            148
# 27317  469181a156678629  1249175233            129
#
#                                                     path  rating      status  \
# 20240  Advertising;Ancient_Greece;<;United_States;<;A...     4.0    finished
# 25087  Spacecraft_propulsion;Mars_Reconnaissance_Orbi...     4.0    finished
# 57329  New_Zealand;United_Kingdom;England;London;Cult...     NaN  unfinished
# 5411                     Internet;German_language;Nazism     NaN    finished
# 76148                                  13th_century;Time     NaN  unfinished
# 3657   David_Beckham;England;Jet_engine;Hydrogen;Heli...     1.0    finished
# 3537   Computer_science;Bioinformatics;Chemistry;Crys...     NaN    finished
# 17751  Ghana;England;Germany;Albert_Einstein;Quantum_...     NaN    finished
# 39333  Glaciology;Geology;Crust_%28geology%29;Contine...     3.0    finished
# 27317  Ice_hockey;Cricket;<;Denmark;Sunlight;Photosyn...     2.0    finished
#
#                target     type
# 20240      Stonehenge      NaN
# 25087      Bald_Eagle      NaN
# 57329       Krazy_Kat  timeout
# 5411           Nazism      NaN
# 76148  Climate_change  restart
# 3657         Actinium      NaN
# 3537      Edible_salt      NaN
# 17751   String_theory      NaN
# 39333       Gardening      NaN
# 27317       Sunflower      NaN

# %%
clean_merge.fillna('finished', inplace=True)
clean_merge.to_csv('clean_merge.csv')
clean_merge.sample(10)
# Out:
# /var/folders/hy/zygvvrm928n5d36wdcsnnkg40000gn/T/ipykernel_15583/2054268849.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'finished' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   clean_merge.fillna('finished', inplace=True)
#         hashedIpAddress   timestamp  durationInSec  \
# 69276  546557f16be18156  1365780793              5
# 73383  21bf0de12623db9d  1380324312            246
# 65099  11ef55361d13da9c  1351304221             97
# 15294  1afd1270383bc1fc  1388204772            157
# 61261  6f7e60880ae91e69  1344153997            181
# 53245  443d7b8528e2e471  1300598434            967
# 4435   1359a8ee0d6e01c7  1249083976            130
# 60565  6594d284353701cc  1340888110             28
# 29614  1d6271903dd9e42c  1369165394             42
# 36677  14adab216bfe1e0b  1236047974            166
#
#                                                     path    rating  \
# 69276                           Data_Encryption_Standard  finished
# 73383                        Detroit%2C_Michigan;Chicago  finished
# 65099  Mars_Exploration_Rover;Cornell_University;Chem...  finished
# 15294  Brain;Mind;Linguistics;Language;Communication;...  finished
# 61261  Exploration_of_Mars;Europe;British_Isles;Great...  finished
# 53245  Theatre;Opera;Richard_Wagner;Germany;Country;E...  finished
# 4435                Evolution;United_States;Irish_people       2.0
# 60565                               First_Macedonian_War  finished
# 29614                          Honey;Water;Fish;Aquarium       3.0
# 36677  Che_Guevara;DNA;Animal;Mammal;Chordate;<;Lion;...       3.0
#
#            status                  target      type
# 69276  unfinished             Vampire_bat   timeout
# 73383  unfinished  Royal_National_Theatre   timeout
# 65099  unfinished             Engineering   timeout
# 15294    finished               Telephone  finished
# 61261  unfinished            Chelsea_F.C.   restart
# 53245  unfinished                   Zebra   restart
# 4435     finished            Irish_people  finished
# 60565  unfinished                    Love   restart
# 29614    finished                Aquarium  finished
# 36677    finished                    Bear  finished
